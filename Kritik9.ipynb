# %%
import sympy as sp

x, y = sp.symbols('x y')

# %%
# a)

h = sp.exp(x)*sp.sin(y)*y**3
## First partials
# Differentiate f with respect to x
dh_dx = sp.diff(h, x)

# Differentiate f with respect to x
dh_dy = sp.diff(h, y)

#print them both

print ("the partial wrt to x is : ", dh_dx)
print ("the partial wrt to y is : ", dh_dy)
# Out:
# the partial wrt to x is :  y**3*exp(x)*sin(y)
# the partial wrt to y is :  y**3*exp(x)*cos(y) + 3*y**2*exp(x)*sin(y)

# %%
# b)

g = ((x**2)*y)+(x*(y**2))
dg_dx = sp.diff(g, x)
#print (dg_dx)

dg_dy = sp.diff(g, y)
#print (dg_dy)

gradient_vector = (dg_dx, dg_dy)
print ("the gradient vector is ", gradient_vector)

#gradient vector at 1, -1

x=1
y=-1
grad_vector=(2*x*y + y**2, x**2 + 2*x*y)
print ("the gradient vector at (1,-1) is ", grad_vector)
# Out:
# the gradient vector is  (2*x*y + y**2, x**2 + 2*x*y)
# the gradient vector at (1,-1) is  (-1, -1)

# %%
# c)

#writing these again cause its being annoying

import sympy as sp

x, y = sp.symbols('x y')


# Define function p
p = sp.log((x**2) + (y**2))

# First partial wrt x

dp_dx = sp.diff(p, x)
print("first partial wrt x is : ", dp_dx)

# second partial wrt x

dp_dx2 = sp.diff(dp_dx, x)
print ("second partial wrt x is : ", dp_dx2)

print ("   ")

# first partial wrt y

dp_dy = sp.diff(p, y)
print("first partial wrt y is : ", dp_dy)

#second partial wrt y

dp_dy2 = sp.diff(dp_dy, y)
print ("second partial wrt y is : ", dp_dy2)

print ("   ")

# mixed partial

dp_dxy = sp.diff(dp_dx, y)
print ("mixed partial is : ", dp_dxy)
# Out:
# first partial wrt x is :  2*x/(x**2 + y**2)
# second partial wrt x is :  -4*x**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
#
# first partial wrt y is :  2*y/(x**2 + y**2)
# second partial wrt y is :  -4*y**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
#
# mixed partial is :  -4*x*y/(x**2 + y**2)**2

# %%
# d)

#Import the necessary libraries:

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the function using SymPy:

x, y = sp.symbols('x y')
j = x**3 - 3*x*y + y**3

# Convert the SymPy expression to a numerical function:

j_func = sp.lambdify((x, y), j, 'numpy')

# Create a grid of x and y values and evaluate j on this grid:

x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = j_func(X, Y)

# Plot the contour:

plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour plot of $j(x, y) = x^3 - 3xy + y^3$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
# e) I'm choosing the cool 3D bell curve function

#Import the necessary libraries:

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the function using SymPy:

x, y = sp.symbols('x y')
j = sp.exp(-1*((x**2)+(y**2)))

# Convert the SymPy expression to a numerical function:

j_func = sp.lambdify((x, y), j, 'numpy')

# Create a grid of x and y values and evaluate j on this grid:

x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = j_func(X, Y)

# Plot the contour:

plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour plot of $j(x, y) = e^(-(x^2+y^2))$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()
